# %% [markdown]
# <a href="https://colab.research.google.com/github/psbhargava/CarDamaged-Classification-Assessment/blob/master/4_App_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
import tensorflow
print(tensorflow.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 13516784690216325098, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 9650289882512778856
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 17348581398968184744
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15956161332
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 17907808314600181159
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
import os
import json
import h5py
import urllib
import numpy as np
import pickle as pk

from keras import applications
from keras.utils.data_utils import get_file
from keras.models import Sequential, load_model
from IPython.display import Image, display, clear_output
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Input

# %%
first_gate = applications.DenseNet201(weights='imagenet')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet201_weights_tf_dim_ordering_tf_kernels.h5
# 82526208/82524592 [==============================] - 17s 0us/step

# %%
! wget https://car-damage-datasets.s3.amazonaws.com/Damaged_densenet_final.h5
# Out:
# --2020-04-25 06:47:14--  https://car-damage-datasets.s3.amazonaws.com/Damaged_densenet_final.h5
# Resolving car-damage-datasets.s3.amazonaws.com (car-damage-datasets.s3.amazonaws.com)... 52.217.44.244
# Connecting to car-damage-datasets.s3.amazonaws.com (car-damage-datasets.s3.amazonaws.com)|52.217.44.244|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 399511056 (381M) [application/x-www-form-urlencoded]
# Saving to: ‘Damaged_densenet_final.h5’
#
# Damaged_densenet_fi 100%[===================>] 381.00M  36.4MB/s    in 11s
#
# 2020-04-25 06:47:25 (34.0 MB/s) - ‘Damaged_densenet_final.h5’ saved [399511056/399511056]

# %%
damage_model = load_model('/content/Damaged_densenet_final.h5')

# %%
# !wget https://car-damage-datasets.s3.amazonaws.com/Location_densenet_final.h5
# Out:
# --2020-04-25 06:48:58--  https://car-damage-datasets.s3.amazonaws.com/Location_densenet_final.h5
# Resolving car-damage-datasets.s3.amazonaws.com (car-damage-datasets.s3.amazonaws.com)... 52.216.92.35
# Connecting to car-damage-datasets.s3.amazonaws.com (car-damage-datasets.s3.amazonaws.com)|52.216.92.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 327556000 (312M) [application/x-www-form-urlencoded]
# Saving to: ‘Location_densenet_final.h5’
#
# Location_densenet_f 100%[===================>] 312.38M  35.6MB/s    in 9.4s
#
# 2020-04-25 06:49:08 (33.1 MB/s) - ‘Location_densenet_final.h5’ saved [327556000/327556000]

# %%
location_model = load_model('/content/Location_densenet_final.h5')

# %%
# !wget https://car-damage-datasets.s3.amazonaws.com/Severity_densenet_final.h5
# Out:
# --2020-04-25 06:50:25--  https://car-damage-datasets.s3.amazonaws.com/Severity_densenet_final.h5
# Resolving car-damage-datasets.s3.amazonaws.com (car-damage-datasets.s3.amazonaws.com)... 52.216.177.115
# Connecting to car-damage-datasets.s3.amazonaws.com (car-damage-datasets.s3.amazonaws.com)|52.216.177.115|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 327556000 (312M) [application/x-www-form-urlencoded]
# Saving to: ‘Severity_densenet_final.h5’
#
# Severity_densenet_f 100%[===================>] 312.38M  35.6MB/s    in 9.5s
#
# 2020-04-25 06:50:35 (33.0 MB/s) - ‘Severity_densenet_final.h5’ saved [327556000/327556000]

# %%
severity_model = load_model('/content/Severity_densenet_final.h5')

# %%
# !wget https://car-damage-datasets.s3.amazonaws.com/vgg16_cat_list.pk
# Out:
# --2020-04-25 06:51:57--  https://car-damage-datasets.s3.amazonaws.com/vgg16_cat_list.pk
# Resolving car-damage-datasets.s3.amazonaws.com (car-damage-datasets.s3.amazonaws.com)... 52.216.184.131
# Connecting to car-damage-datasets.s3.amazonaws.com (car-damage-datasets.s3.amazonaws.com)|52.216.184.131|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1745 (1.7K) [binary/octet-stream]
# Saving to: ‘vgg16_cat_list.pk’
#
# vgg16_cat_list.pk   100%[===================>]   1.70K  --.-KB/s    in 0s
#
# 2020-04-25 06:51:57 (86.7 MB/s) - ‘vgg16_cat_list.pk’ saved [1745/1745]

# %%
with open('/content/vgg16_cat_list.pk', 'rb') as f:
    cat_list = pk.load(f)

# %% [markdown]
# ## First Gate Setup - Car or Not?

# %%
CLASS_INDEX = None
CLASS_INDEX_PATH = 'https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json'

def get_predictions(preds, top=5):
    global CLASS_INDEX
    
    if len(preds.shape) != 2 or preds.shape[1] != 1000:
        raise ValueError('`decode_predictions` expects '
                         'a batch of predictions '
                         '(i.e. a 2D array of shape (samples, 1000)). '
                         'Found array with shape: ' + str(preds.shape))
    if CLASS_INDEX is None:
        fpath = get_file('imagenet_class_index.json',CLASS_INDEX_PATH,cache_subdir='models')
        CLASS_INDEX = json.load(open(fpath))
    results = []

    for pred in preds:
        top_indices = pred.argsort()[-top:][::-1]
        result = [tuple(CLASS_INDEX[str(i)]) + (pred[i],) for i in top_indices]
        result.sort(key=lambda x: x[2], reverse=True)
        results.append(result)
    return results

# %%
def prepare_img_224(img_path):
    urllib.request.urlretrieve(img_path, 'save.jpg') # or other way to upload image
    img = load_img('save.jpg', target_size=(224, 224))
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return x

# %%
def car_categories_gate(img_224, model):
    print ("Validating that this is a picture of your car --> ")
    out = model.predict(img_224)
    top = get_predictions(out, top=5)
    for j in top[0]:
        if j[0:2] in cat_list: # print j[0:2]
            return True # "Validation complete - proceed to damage evaluation"
    return False # "Are you sure this is a picture of your car? Please take another picture (try a different angle or lighting) and try again."

# %% [markdown]
# ## Second Gate Setup - Damaged or Whole?

# %%
def prepare_img_256(img_path):
    urllib.request.urlretrieve(img_path, 'save.jpg') # or other way to upload image
    img = load_img('save.jpg', target_size=(256, 256)) # this is a PIL image 
    x = img_to_array(img) # this is a Numpy array with shape (3, 256, 256)
    x = x.reshape((1,) + x.shape)/255
    return x

# %%
def car_damage_gate(img_256, model):
    print ("Validating that damage exists --> ")
    pred = model.predict(img_256)
    if pred[0][0] >=.5:
        return True # print "Validation complete - proceed to location and severity determination"
    else:
        return False
        # print "Are you sure that your car is damaged? Please submit another picture of the damage."
        # print "Hint: Try zooming in/out, using a different angle or different lighting"

# %% [markdown]
# ## Location and Severity Assessment

# %%
def location_assessment(img_256, model):
    print ("Determining location of damage --> ")
    pred = model.predict(img_256)
    pred_label = np.argmax(pred, axis=1)
    d = {0: 'Front', 1: 'Rear', 2: 'Side'}
    for key in d.keys():
        if pred_label[0] == key:
            print ("Assessment: {} damage to vehicle".format(d[key]))
    print ("Location assessment complete.")

# %%
def severity_assessment(img_256, model):
    print ("Determining severity of damage --> ")
    pred = model.predict(img_256)
    pred_label = np.argmax(pred, axis=1)
    d = {0: 'Minor', 1: 'Moderate', 2: 'Severe'}
    for key in d.keys():
        if pred_label[0] == key:
            print ("Assessment: {} damage to vehicle".format(d[key]))
    print ("Severity assessment complete.")

# %%
# load models
def engine(img_path):
    img_224 = prepare_img_224(img_path)
    g1 = car_categories_gate(img_224, first_gate)

    display(Image('save.jpg', width=300))

    if g1 is False:
        print ("Are you sure this is a picture of your car? Please submit another picture of the damage.")
        print ("Hint: Try zooming in/out, using a different angle or different lighting.")
        return
        

    img_256 = prepare_img_256(img_path)
    g2 = car_damage_gate(img_256, damage_model)

    # if g2 is False:
    #     print ("Are you sure that your car is damaged? Please submit another picture of the damage.")
    #     print ("Hint: Try zooming in/out, using a different angle or different lighting.")
        

    x = location_assessment(img_256, location_model)
    y = severity_assessment(img_256, severity_model)

# %%
engine('https://www.denofgeek.com/wp-content/uploads/2019/07/spider-man-far-from-home-ending-explained.jpg?fit=1920%2C1080')
# Out:
# Validating that this is a picture of your car -->
# Are you sure this is a picture of your car? Please submit another picture of the damage.
# Hint: Try zooming in/out, using a different angle or different lighting.

# %%
engine('https://media.vanityfair.com/photos/5d2750b1abb5c9000873bced/master/w_2560%2Cc_limit/lion-king-review.jpg')
# Out:
# Validating that this is a picture of your car -->
# Are you sure this is a picture of your car? Please submit another picture of the damage.
# Hint: Try zooming in/out, using a different angle or different lighting.

# %%
engine('https://boygeniusreport.files.wordpress.com/2017/09/dented-car.jpg?quality=98&strip=all&w=782')
# Out:
# Validating that this is a picture of your car -->
# Validating that damage exists -->
# Determining location of damage -->
# Assessment: Side damage to vehicle
# Location assessment complete.
# Determining severity of damage -->
# Assessment: Minor damage to vehicle
# Severity assessment complete.

# %%
engine('data:image/jpeg;base64,...')
# Out:
# Validating that this is a picture of your car -->
# Validating that damage exists -->
# Determining location of damage -->
# Assessment: Front damage to vehicle
# Location assessment complete.
# Determining severity of damage -->
# Assessment: Severe damage to vehicle
# Severity assessment complete.

# %%
engine('https://thumbs.dreamstime.com/z/car-accident-damage-24448330.jpg')
# Out:
# Validating that this is a picture of your car -->
# Validating that damage exists -->
# Determining location of damage -->
# Assessment: Front damage to vehicle
# Location assessment complete.
# Determining severity of damage -->
# Assessment: Moderate damage to vehicle
# Severity assessment complete.

# %%
engine('data:image/jpeg;base64,...')
# Out:
# Validating that this is a picture of your car -->
# Validating that damage exists -->
# Determining location of damage -->
# Assessment: Rear damage to vehicle
# Location assessment complete.
# Determining severity of damage -->
# Assessment: Minor damage to vehicle
# Severity assessment complete.
