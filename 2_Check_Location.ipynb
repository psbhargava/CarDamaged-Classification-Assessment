# %% [markdown]
# <a href="https://colab.research.google.com/github/psbhargava/CarDamaged-Classification-Assessment/blob/master/2_Check_Location.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
import tensorflow
print(tensorflow.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 10249188587996025206, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 17605076488002082249
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 8663718329217552559
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11330115994
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1975796024747754693
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
import os
import json
import urllib
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline


from keras import optimizers
from keras import applications
from keras.models import Sequential, Model 
from keras.models import Sequential,load_model
from keras.callbacks import ModelCheckpoint, History
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Using TensorFlow backend.

# %%
# !wget https://car-damage-datasets.s3.amazonaws.com/data2a.zip
# Out:
# --2020-04-24 16:51:47--  https://car-damage-datasets.s3.amazonaws.com/data2a.zip
# Resolving car-damage-datasets.s3.amazonaws.com (car-damage-datasets.s3.amazonaws.com)... 52.216.244.132
# Connecting to car-damage-datasets.s3.amazonaws.com (car-damage-datasets.s3.amazonaws.com)|52.216.244.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10766638 (10M) [application/zip]
# Saving to: ‘data2a.zip’
#
# data2a.zip          100%[===================>]  10.27M  34.8MB/s    in 0.3s
#
# 2020-04-24 16:51:48 (34.8 MB/s) - ‘data2a.zip’ saved [10766638/10766638]

# %%
# !unzip data2a.zip
# Out:
# Archive:  data2a.zip
#    creating: train/
#    creating: train/front/
#   inflating: train/front/0001.jpeg
#   inflating: train/front/0002.JPEG
#   inflating: train/front/0003.JPEG
#   inflating: train/front/0004.JPEG
#   inflating: train/front/0005.JPEG
#   inflating: train/front/0006.JPEG
#   inflating: train/front/0007.JPEG
#   inflating: train/front/0008.jpeg
#   inflating: train/front/0009.JPEG
#   inflating: train/front/0010.JPEG
#   inflating: train/front/0011.JPEG
#   inflating: train/front/0012.jpeg
#   inflating: train/front/0013.JPEG
#   inflating: train/front/0014.JPEG
#   inflating: train/front/0015.JPEG
#   inflating: train/front/0016.JPEG
#   inflating: train/front/0017.JPEG
#   inflating: train/front/0018.JPEG
#   inflating: train/front/0019.JPEG
#   inflating: train/front/0020.jpeg
#   inflating: train/front/0021.JPEG
#   inflating: train/front/0022.JPEG
#   inflating: train/front/0023.JPEG
#   inflating: train/front/0024.JPEG
#   inflating: train/front/0025.jpeg
#   inflating: train/front/0026.JPEG
#   inflating: train/front/0027.JPEG
#   inflating: train/front/0028.JPEG
#   inflating: train/front/0029.JPEG
#   inflating: train/front/0030.JPEG
#   inflating: train/front/0031.JPEG
#   inflating: train/front/0032.JPEG
#   inflating: train/front/0033.JPEG
#   inflating: train/front/0034.JPEG
#   inflating: train/front/0035.jpeg
#   inflating: train/front/0036.JPEG
#   inflating: train/front/0037.JPEG
#   inflating: train/front/0038.JPEG
#   inflating: train/front/0039.JPEG
#   inflating: train/front/0040.JPEG
#   inflating: train/front/0041.JPEG
#   inflating: train/front/0042.JPEG
#   inflating: train/front/0043.JPEG
#   inflating: train/front/0044.JPEG
#   inflating: train/front/0045.JPEG
#   inflating: train/front/0046.jpeg
#   inflating: train/front/0047.JPEG
#   inflating: train/front/0048.JPEG
#   inflating: train/front/0049.JPEG
#   inflating: train/front/0050.JPEG
#   inflating: train/front/0051.JPEG
#   inflating: train/front/0052.JPEG
#   inflating: train/front/0053.JPEG
#   inflating: train/front/0054.jpeg
#   inflating: train/side/0016.JPEG
#   inflating: train/side/0017.JPEG
#   inflating: train/side/0018.JPEG
#   inflating: train/side/0019.JPEG
#   inflating: train/side/0020.JPEG
#   inflating: train/side/0021.JPEG
#   inflating: train/side/0022.JPEG
#   inflating: train/side/0023.JPEG
#   inflating: train/side/0024.JPEG
#   inflating: train/side/0025.JPEG
#   inflating: train/side/0026.JPEG
#   inflating: train/side/0027.JPEG
#   inflating: train/side/0028.JPEG
#   inflating: train/side/0029.JPEG
#   inflating: train/side/0030.JPEG
#   inflating: train/side/0031.JPEG
#   inflating: train/side/0032.JPEG
#   inflating: train/side/0033.JPEG
#   inflating: train/side/0034.JPEG
#   inflating: train/side/0035.JPEG
#   inflating: train/side/0036.JPEG
#   inflating: train/side/0037.JPEG
#   inflating: train/side/0038.JPEG
#   inflating: train/side/0039.JPEG
#   inflating: train/side/0040.JPEG
#   inflating: train/side/0041.JPEG
#   inflating: train/side/0042.JPEG
#   inflating: train/side/0043.JPEG
#   inflating: train/side/0044.JPEG
#   inflating: train/side/0045.JPEG
#   inflating: train/side/0046.JPEG
#   inflating: train/side/0047.JPEG
#   inflating: train/side/0048.JPEG
#   inflating: train/side/0049.JPEG
#   inflating: train/side/0050.JPEG
#   inflating: train/side/0051.JPEG
#   inflating: train/side/0052.JPEG
#   inflating: train/side/0053.JPEG
#   inflating: train/side/0054.JPEG
#   inflating: train/side/0055.JPEG
#   inflating: train/side/0056.JPEG
#   inflating: train/side/0057.jpeg
#   inflating: train/side/0058.JPEG
#   inflating: train/side/0059.JPEG
#   inflating: train/side/0060.JPEG
#   inflating: train/side/0061.JPEG
#   inflating: train/side/0062.JPEG
#   inflating: train/side/0063.jpeg
#   inflating: train/side/0064.JPEG
#   inflating: train/side/0065.JPEG
#   inflating: train/side/0066.JPEG
#   inflating: train/side/0067.JPEG
#   inflating: train/side/0068.JPEG
#   inflating: train/side/0069.JPEG
#   inflating: train/side/0070.JPEG
#   inflating: train/side/0071.JPEG
#   inflating: train/side/0072.JPEG
#   inflating: train/side/0073.JPEG
#   inflating: train/side/0074.JPEG
#   inflating: train/side/0075.jpeg
#   inflating: train/side/0076.jpeg
#   inflating: train/side/0077.JPEG
#   inflating: train/side/0078.JPEG
#   inflating: train/side/0079.JPEG
#   inflating: train/side/0080.JPEG
#   inflating: train/side/0081.JPEG
#   inflating: train/side/0082.JPEG
#   inflating: train/side/0083.JPEG
#   inflating: train/side/0084.JPEG
#   inflating: train/side/0085.JPEG
#   inflating: train/side/0086.JPEG
#   inflating: train/side/0087.JPEG
#   inflating: train/side/0088.JPEG
#   inflating: train/side/0089.JPEG
#   inflating: train/side/0090.JPEG
#   inflating: train/side/0091.jpeg
#   inflating: train/side/0092.JPEG
#   inflating: train/side/0093.JPEG
#   inflating: train/side/0094.JPEG
#   inflating: train/side/0095.JPEG
#   inflating: train/side/0096.JPEG
#   inflating: train/side/0097.jpeg
#   inflating: train/side/0098.JPEG
#   inflating: train/side/0099.JPEG
#   inflating: train/side/0100.JPEG
#   inflating: train/side/0101.jpeg
#   inflating: train/side/0102.JPEG
#   inflating: train/side/0103.JPEG
#   inflating: train/side/0104.JPEG
#   inflating: train/side/0105.jpeg
#   inflating: train/side/0106.jpeg
#   inflating: train/side/0107.JPEG
#   inflating: train/side/0108.jpeg
#   inflating: train/side/0109.JPEG
#   inflating: train/side/0110.JPEG
#   inflating: train/side/0111.JPEG
#   inflating: train/side/0112.JPEG
#   inflating: train/side/0113.JPEG
#   inflating: train/side/0114.JPEG
#   inflating: train/side/0115.JPEG
#   inflating: train/side/0116.JPEG
#   inflating: train/side/0117.JPEG
#   inflating: train/side/0118.JPEG
#   inflating: train/side/0119.JPEG
#   inflating: train/side/0120.JPEG
#   inflating: train/side/0121.JPEG
#   inflating: train/side/0122.JPEG
#   inflating: train/side/0123.JPEG
#   inflating: train/side/0124.JPEG
#   inflating: train/side/0125.JPEG
#   inflating: train/side/0126.JPEG
#   inflating: train/side/0127.JPEG
#   inflating: train/side/0128.JPEG
#   inflating: train/side/0129.JPEG
#   inflating: train/side/0130.JPEG
#   inflating: train/side/0131.JPEG
#   inflating: train/side/0132.JPEG
#   inflating: train/side/0133.JPEG
#   inflating: train/side/0134.JPEG
#   inflating: train/side/0135.JPEG
#   inflating: train/side/0136.JPEG
#   inflating: train/side/0137.JPEG
#   inflating: train/side/0138.JPEG
#   inflating: train/side/0139.JPEG
#   inflating: train/side/0140.JPEG
#   inflating: train/side/0141.JPEG
#   inflating: train/side/0142.JPEG
#   inflating: train/side/0143.JPEG
#   inflating: train/side/0144.jpeg
#   inflating: train/side/0145.jpeg
#   inflating: train/side/0146.JPEG
#   inflating: train/side/0147.JPEG
#   inflating: train/side/0148.JPEG
#   inflating: train/side/0149.jpeg
#   inflating: train/side/0150.JPEG
#   inflating: train/side/0151.JPEG
#   inflating: train/side/0152.JPEG
#   inflating: train/side/0153.jpeg
#   inflating: train/side/0154.JPEG
#   inflating: train/side/0155.JPEG
#   inflating: train/side/0156.JPEG
#   inflating: train/side/0157.JPEG
#   inflating: train/side/0158.jpeg
#   inflating: train/side/0159.JPEG
#   inflating: train/side/0160.JPEG
#   inflating: train/side/0161.jpeg
#   inflating: train/side/0162.JPEG
#   inflating: train/side/0163.JPEG
#   inflating: train/side/0164.jpeg
#   inflating: train/side/0165.JPEG
#   inflating: train/side/0166.JPEG
#   inflating: train/side/0167.JPEG
#   inflating: train/side/0168.JPEG
#   inflating: train/side/0169.JPEG
#   inflating: train/side/0170.jpeg
#   inflating: train/side/0171.JPEG
#   inflating: train/side/0172.JPEG
#   inflating: train/side/0173.JPEG
#   inflating: train/side/0174.JPEG
#   inflating: train/side/0175.JPEG
#   inflating: train/side/0176.JPEG
#   inflating: train/side/0177.JPEG
#   inflating: train/side/0178.JPEG
#   inflating: train/side/0179.JPEG
#   inflating: train/side/0180.JPEG
#   inflating: train/side/0181.JPEG
#   inflating: train/side/0182.JPEG
#   inflating: train/side/0183.JPEG
#   inflating: train/side/0184.JPEG
#   inflating: train/side/0185.JPEG
#   inflating: train/side/0186.JPEG
#   inflating: train/side/0187.JPEG
#   inflating: train/side/0188.JPEG
#   inflating: train/side/0189.JPEG
#   inflating: train/side/0190.JPEG
#   inflating: train/side/0191.JPEG
#   inflating: train/side/0192.JPEG
#   inflating: train/side/0193.JPEG
#   inflating: train/side/0194.jpeg
#   inflating: train/side/0195.JPEG
#   inflating: train/side/0196.JPEG
#   inflating: train/side/0197.JPEG
#   inflating: train/side/0198.JPEG
#   inflating: train/side/0199.JPEG
#   inflating: train/side/0200.JPEG
#   inflating: train/side/0201.JPEG
#   inflating: train/side/0202.JPEG
#   inflating: train/side/0203.JPEG
#   inflating: train/side/0204.JPEG
#   inflating: train/side/0205.JPEG
#   inflating: train/side/0206.JPEG
#   inflating: train/side/0207.JPEG
#   inflating: train/side/0208.JPEG
#   inflating: train/side/0209.jpeg
#   inflating: train/side/0210.JPEG
#   inflating: train/side/0211.JPEG
#   inflating: train/side/0212.JPEG
#   inflating: train/side/0213.JPEG
#   inflating: train/side/0214.JPEG
#   inflating: train/side/0215.JPEG
#   inflating: train/side/0216.JPEG
#   inflating: train/side/0217.JPEG
#   inflating: train/side/0218.JPEG
#   inflating: train/side/0219.JPEG
#   inflating: train/side/0220.JPEG
#   inflating: train/side/0221.JPEG
#   inflating: train/side/0222.JPEG
#   inflating: train/side/0223.JPEG
#   inflating: train/side/0224.JPEG
#   inflating: train/side/0225.JPEG
#   inflating: train/side/0226.JPEG
#   inflating: train/side/0227.JPEG
#   inflating: train/side/0228.JPEG
#   inflating: train/side/0229.JPEG
#   inflating: train/side/0230.jpeg
#   inflating: train/side/0231.JPEG
#   inflating: train/side/0232.JPEG
#   inflating: train/side/0233.JPEG
#   inflating: train/side/0234.JPEG
#   inflating: train/side/0235.JPEG
#   inflating: train/side/0236.JPEG
#   inflating: train/side/0237.JPEG
#   inflating: train/side/0238.JPEG
#   inflating: train/side/0239.JPEG
#   inflating: train/side/0240.JPEG
#   inflating: train/side/0241.JPEG
#   inflating: train/side/0242.JPEG
#   inflating: train/side/0243.JPEG
#   inflating: train/side/0244.jpeg
#   inflating: train/side/0245.JPEG
#   inflating: train/side/0246.JPEG
#   inflating: train/side/0247.JPEG
#   inflating: train/side/0248.JPEG
#   inflating: train/side/0249.JPEG
#   inflating: train/side/0250.JPEG
#   inflating: train/side/0251.JPEG
#   inflating: train/side/0252.JPEG
#   inflating: train/side/0253.JPEG
#   inflating: train/side/0254.JPEG
#   inflating: train/side/0255.JPEG
#   inflating: train/side/0256.JPEG
#   inflating: train/side/0257.jpeg
#   inflating: train/side/0258.JPEG
#   inflating: train/side/0259.JPEG
#   inflating: train/side/0260.JPEG
#   inflating: train/side/0261.JPEG
#   inflating: train/side/0262.JPEG
#   inflating: train/side/0263.JPEG
#   inflating: train/side/0264.JPEG
#   inflating: train/side/0265.JPEG
#   inflating: train/side/0266.JPEG
#   inflating: train/side/0267.jpeg
#   inflating: train/side/0268.JPEG
#   inflating: train/side/0269.JPEG
#   inflating: train/side/0270.JPEG
#   inflating: train/side/0271.jpeg
#   inflating: train/side/0272.JPEG
#   inflating: valid/side/0035.JPEG
#   inflating: valid/side/0036.JPEG
#   inflating: valid/side/0037.JPEG
#   inflating: valid/side/0038.JPEG
#   inflating: valid/side/0039.JPEG
#   inflating: valid/side/0040.JPEG
#   inflating: valid/side/0041.JPEG
#   inflating: valid/side/0042.JPEG
#   inflating: valid/side/0043.JPEG
#   inflating: valid/side/0044.JPEG
#   inflating: valid/side/0045.JPEG
#   inflating: valid/side/0046.JPEG
#   inflating: valid/side/0047.JPEG
#   inflating: valid/side/0048.jpeg

# %%
img_width = 256
img_height = 256
train_data_dir = '/content/train'
valid_data_dir = '/content/valid'
fine_tuned_model_path = 'ft_model.h5'

train_samples = [len(os.listdir(train_data_dir+'/'+i)) for i in sorted(os.listdir(train_data_dir))]
nb_train_samples = sum(train_samples)
print(nb_train_samples)

validation_samples = [len(os.listdir(valid_data_dir+'/'+i)) for i in sorted(os.listdir(valid_data_dir))]
nb_validation_samples = sum(validation_samples)
print(nb_validation_samples)

epochs = 50 #150
batch_size = 8
# Out:
# 979
# 171

# %%
model = applications.DenseNet201(weights = "imagenet", include_top=False, input_shape = (img_width, img_height, 3))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step

# %%
model.layers[703]

# %%
for layer in model.layers[:703]:
    layer.trainable = False

# %%
x = model.output

x = Flatten()(x)
x = Dense(256, activation="relu")(x)

x = Dropout(0.5)(x)
x = Dense(256, activation="relu")(x)
predictions = Dense(3, activation="softmax")(x)

# %%
model_final = Model(input = model.input, output = predictions)

model_final.compile(loss = "categorical_crossentropy", optimizer = optimizers.SGD(lr=0.00001, momentum=0.9), 
                    metrics=["accuracy"])

train_datagen = ImageDataGenerator(rescale = 1./255,horizontal_flip = True,fill_mode = "nearest",zoom_range = 0.2,
                                   width_shift_range = 0.2,height_shift_range=0.2,shear_range=0.2,rotation_range=40)

test_datagen = ImageDataGenerator(rescale = 1./255,horizontal_flip = True,fill_mode = "nearest",zoom_range = 0.2,
                                  width_shift_range = 0.2,height_shift_range=0.2,shear_range=0.2,rotation_range=40)

train_generator = train_datagen.flow_from_directory(train_data_dir,target_size = (img_height, img_width),
                                                    batch_size = batch_size, class_mode = "categorical")

validation_generator = test_datagen.flow_from_directory(valid_data_dir,target_size = (img_height, img_width),
                                                        class_mode = "categorical")

checkpoint = ModelCheckpoint("Location_densenet_final.h5", monitor='val_acc', verbose=1, save_best_only=True, 
                             save_weights_only=False, mode='auto', period=1)

early = EarlyStopping(monitor='val_acc', min_delta=0, patience=10, verbose=1, mode='auto')

model_final.fit_generator(train_generator,samples_per_epoch = nb_train_samples,epochs = epochs,
                          validation_data = validation_generator,nb_val_samples = nb_validation_samples,
                          callbacks = [checkpoint]) #,early
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   """Entry point for launching an IPython kernel.
# Found 979 images belonging to 3 classes.
# Found 171 images belonging to 3 classes.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., epochs=50, validation_data=<keras.pre..., callbacks=[<keras.ca..., steps_per_epoch=122, validation_steps=171)`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/50
# 122/122 [==============================] - 151s 1s/step - loss: 1.2671 - accuracy: 0.3708 - val_loss: 1.1064 - val_accuracy: 0.4236
# Epoch 2/50
#   1/122 [..............................] - ETA: 20s - loss: 1.0220 - accuracy: 0.5000
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
#
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-af216a99e7fb> in <module>()
#      23 model_final.fit_generator(train_generator,samples_per_epoch = nb_train_samples,epochs = epochs,
#      24                           validation_data = validation_generator,nb_val_samples = nb_validation_samples,
# ---> 25                           callbacks = [checkpoint]) #,early
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     240                             validation_steps,
#     241                             callbacks=callbacks,
# --> 242                             workers=0)
#     243                     else:
#     244                         # No need for try/except because
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in evaluate_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    1789             workers=workers,
#    1790             use_multiprocessing=use_multiprocessing,
# -> 1791             verbose=verbose)
#    1792
#    1793     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in evaluate_generator(model, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#     399             outs = model.test_on_batch(x, y,
#     400                                        sample_weight=sample_weight,
# --> 401                                        reset_metrics=False)
#     402             outs = to_list(outs)
#     403             outs_per_batch.append(outs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in test_on_batch(self, x, y, sample_weight, reset_metrics)
#    1557             ins = x + y + sample_weights
#    1558         self._make_test_function()
# -> 1559         outputs = self.test_function(ins)
#    1560
#    1561         if reset_metrics:
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
def location_estimator(image_path, model):
    print ("Determining location of damage...")
    urllib.request.urlretrieve(image_path, 'save.jpg') # or other way to upload image
    img = load_img('save.jpg', target_size=(256, 256)) # this is a PIL image 
    x = img_to_array(img) # this is a Numpy array with shape (3, 256, 256)
    x = x.reshape((1,) + x.shape)/255 # this is a Numpy array with shape (1, 3, 256, 256)
    pred = model.predict(x)
    pred_label = np.argmax(pred, axis=1)
    print(pred_label)
    plt.imshow(img)
    plt.show()
    d = {0: 'Front', 1: 'Rear', 2: 'Side'}
    for key in d.keys():
        if pred_label[0] == key:
            print ("Assessment: {} damage to vehicle".format(d[key]))
    print ("Location assessment complete.")

# %%
model_final.save_weights("Location_densenet_final.h5")

# %%
location_estimator('data:image/jpeg;base64,...',model_final)
# Out:
# Determining location of damage...
# [2]
# Assessment: Side damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://c8.alamy.com/comp/EKAP5C/car-accident-damage-on-rear-end-usa-EKAP5C.jpg',model_final)
# Out:
# Determining location of damage...
# [1]
# Assessment: Rear damage to vehicle
# Location assessment complete.

# %%
location_estimator('data:image/jpeg;base64,...',model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('http://www.sturtevantauto.com/Content/files/CarBodyDamage.jpg', model_final)
# Out:
# Determining location of damage...
# [1]
# Assessment: Rear damage to vehicle
# Location assessment complete.

# %%
location_estimator('http://1.bp.blogspot.com/-ToQS-qIxYbo/UDNuV5OcVQI/AAAAAAAABdo/tjeQywWiOo0/s200/Key+scratch.jpg', model_final)
# Out:
# Determining location of damage...
# [2]
# Assessment: Side damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://www.libertymutual.com/insurance-content/copy/claims/types-of-car-damage/severe-car-damage.jpg?v=2015030112332273', model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('data:image/jpeg;base64,...', model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('data:image/jpeg;base64,...', model_final)
# Out:
# Determining location of damage...
# [1]
# Assessment: Rear damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://www.side.cr/wp-content/uploads/2018/09/Connecticut-Sell-Damaged-Car.jpg', model_final)
# Out:
# Determining location of damage...
# [2]
# Assessment: Side damage to vehicle
# Location assessment complete.

# %%
location_estimator('data:image/jpeg;base64,...', model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS9Zi5chHQrhlAxtYupxm5wH2SvYDj2T47XJ3ckLI735NjMi2xm9Q', model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQRBUPvifCXSM14dO8WvFcoAQJOVQiRC8ul3YxfvMEb2lFsC0D2', model_final)
# Out:
# Determining location of damage...
# [1]
# Assessment: Rear damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcThpYaPbP4xKXPLaTAP-p3BnkgyElfOKbV5o6VNaqt40ZjvevyO', model_final)
# Out:
# Determining location of damage...
# [1]
# Assessment: Rear damage to vehicle
# Location assessment complete.
